# %%
#Get the first page to extract page numbers
import requests, re
from bs4 import BeautifulSoup

r=requests.get("http://suumo.jp/jj/chintai/ichiran/FR301FC001/?ar=030&bs=040&ta=13&sc=13101&sc=13102&sc=13103&sc=13104&sc=13105&sc=13113&cb=0.0&ct=9999999&et=9999999&cn=9999999&mb=0&mt=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&fw2=")
c=r.content

soup=BeautifulSoup(c,"html.parser")

all=soup.find_all("div",{"class":"cassetteitem"})

all[0].find("span",{"class":"cassetteitem_other-emphasis ui-text--bold"}).text.replace("\n","").replace(" ","")
test = all[0].find("li",{"class","cassetteitem_detail-col1"})
print(test)

page_nr=soup.find_all("ol",{"class":"pagination-parts"})[-1].text
page_nr = [int(s) for s in page_nr.split() if s.isdigit()]
page_nr = page_nr[len(page_nr)-1]

print(page_nr,"pages were found")
# Out:
# <li class="cassetteitem_detail-col1">東京都文京区目白台２</li>
# 533 pages were found

# %%
import re

l=[]
base_url='http://suumo.jp/jj/chintai/ichiran/FR301FC001/?ar=030&bs=040&ta=13&sc=13101&sc=13102&sc=13103&sc=13104&sc=13105&sc=13113&cb=0.0&ct=9999999&et=9999999&cn=9999999&mb=0&mt=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&fw2='

items = []
n = 0

for page in range(1,5,1):
    #print(    )
    r=requests.get(base_url+'&pn='+str(page))
    c=r.content
    #c=r.json()["list"]
    soup=BeautifulSoup(c,"html.parser")
    all = soup.find_all(lambda tag: tag.name == 'div' and 
                                   tag.get('class') == ['cassetteitem'])
    #all=soup.find_all("div",{"class":"cassetteitem"})
    

    
    for item in all:
        d={}
        d["-Title"]=item.find("div",{"class","cassetteitem_content-title"}).text
        d["Locality"]=item.find("li",{"class","cassetteitem_detail-col1"}).text
        # print(item.find_all("li",{"class","cassetteitem_detail-col1"})[0].text
        d["Price"]=item.find("span",{"class","cassetteitem_other-emphasis ui-text--bold"}).text.replace("\n","").replace(" ","")

        #Rooms
        rooms = item.find("table",{"class","cassetteitem_other"}).text
        if 'ワンルーム' in rooms:
            d["Rooms"]=1
        elif '1K' in rooms:
            d["Rooms"]=1
        elif '2K' in rooms:
            d["Rooms"]=2
        else:
            d["Rooms"]="Unknown"
        
        table = item.find_all("table",{"class","cassetteitem_other"})[0]
        nums = re.findall(r'\d+(?:\.\d+)?', str(table))
        d["Size"]=nums[-6]+" m2"
        
        d["Link"]=item.find("td",{"class","ui-text--midium ui-text--bold"}).text
        
        #d[]=item.find_all("",{"",""})[0].text

        l.append(d)

# %%
l
# Out:
# [{'-Title': '久松邸',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区目白台２',
#   'Price': '2.5万円',
#   'Rooms': 1,
#   'Size': '11.6 m2'},
#  {'-Title': '名越荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区赤城下町',
#   'Price': '2.6万円',
#   'Rooms': 1,
#   'Size': '9.9 m2'},
#  {'-Title': '東京メトロ千代田線 千駄木駅 2階建 築43年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区千駄木１',
#   'Price': '2.6万円',
#   'Rooms': 1,
#   'Size': '10 m2'},
#  {'-Title': '司荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区北新宿２',
#   'Price': '2.5万円',
#   'Rooms': 1,
#   'Size': '9 m2'},
#  {'-Title': '川村アパート',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区喜久井町',
#   'Price': '2.6万円',
#   'Rooms': 1,
#   'Size': '8.25 m2'},
#  {'-Title': '都営大江戸線 落合南長崎駅 2階建 築41年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区西落合３',
#   'Price': '2.6万円',
#   'Rooms': 1,
#   'Size': '9.72 m2'},
#  {'-Title': '大和荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区本駒込４',
#   'Price': '2.5万円',
#   'Rooms': 1,
#   'Size': '10.5 m2'},
#  {'-Title': '東京メトロ千代田線 千駄木駅 2階建 築49年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区千駄木３',
#   'Price': '2.9万円',
#   'Rooms': 1,
#   'Size': '12.38 m2'},
#  {'-Title': '寺田アパート',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区千石４',
#   'Price': '2.6万円',
#   'Rooms': 1,
#   'Size': '9 m2'},
#  {'-Title': '河野荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都渋谷区代々木５',
#   'Price': '2.9万円',
#   'Rooms': 1,
#   'Size': '10 m2'},
#  {'-Title': '高栄荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区千駄木５',
#   'Price': '2.8万円',
#   'Rooms': 1,
#   'Size': '9.9 m2'},
#  {'-Title': 'ＪＲ山手線 巣鴨駅 2階建 築53年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区千石４',
#   'Price': '2.6万円',
#   'Rooms': 1,
#   'Size': '9 m2'},
#  {'-Title': 'ＪＲ山手線 巣鴨駅 2階建 築55年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区千石４',
#   'Price': '2.6万円',
#   'Rooms': 1,
#   'Size': '8.7 m2'},
#  {'-Title': '三枝荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区高田馬場４',
#   'Price': '2.9万円',
#   'Rooms': 1,
#   'Size': '10.01 m2'},
#  {'-Title': '山崎荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都渋谷区本町４',
#   'Price': '3万円',
#   'Rooms': 1,
#   'Size': '12.8 m2'},
#  {'-Title': '東京メトロ南北線 東大前駅 2階建 築38年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区本郷６',
#   'Price': '2.9万円',
#   'Rooms': 1,
#   'Size': '12 m2'},
#  {'-Title': 'もたいアパート',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区千駄木５',
#   'Price': '3万円',
#   'Rooms': 1,
#   'Size': '11.34 m2'},
#  {'-Title': '早川荘\u3000別館',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区早稲田南町',
#   'Price': '2.9万円',
#   'Rooms': 1,
#   'Size': '10 m2'},
#  {'-Title': '東京メトロ東西線 早稲田駅 2階建 築56年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区早稲田南町',
#   'Price': '2.9万円',
#   'Rooms': 1,
#   'Size': '10 m2'},
#  {'-Title': '京王新線 幡ヶ谷駅 2階建 築54年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都渋谷区幡ヶ谷１',
#   'Price': '3万円',
#   'Rooms': 1,
#   'Size': '9.72 m2'},
#  {'-Title': 'ＪＲ山手線 高田馬場駅 2階建 築46年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区高田馬場４',
#   'Price': '2.7万円',
#   'Rooms': 1,
#   'Size': '8 m2'},
#  {'-Title': '狩野荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区弁天町',
#   'Price': '2.9万円',
#   'Rooms': 1,
#   'Size': '7.43 m2'},
#  {'-Title': 'プティハウス',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区若松町',
#   'Price': '3万円',
#   'Rooms': 1,
#   'Size': '4.6 m2'},
#  {'-Title': 'ＪＲ中央線 東中野駅 2階建 築40年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区北新宿４',
#   'Price': '2.9万円',
#   'Rooms': 1,
#   'Size': '12 m2'},
#  {'-Title': '越後屋アパート',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区北新宿４',
#   'Price': '2.9万円',
#   'Rooms': 1,
#   'Size': '12 m2'},
#  {'-Title': '京王新線 幡ヶ谷駅 2階建 築50年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都渋谷区幡ヶ谷３',
#   'Price': '3万円',
#   'Rooms': 1,
#   'Size': '13.22 m2'},
#  {'-Title': '都営三田線 春日駅 3階建 築58年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区白山２',
#   'Price': '3万円',
#   'Rooms': 2,
#   'Size': '18.15 m2'},
#  {'-Title': '野口荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区白山２',
#   'Price': '3万円',
#   'Rooms': 2,
#   'Size': '13.2 m2'},
#  {'-Title': '都営大江戸線 西新宿五丁目駅 2階建 築47年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都渋谷区本町４',
#   'Price': '3万円',
#   'Rooms': 1,
#   'Size': '17 m2'},
#  {'-Title': '都営大江戸線 牛込柳町駅 3階建 築49年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区喜久井町',
#   'Price': '2.9万円',
#   'Rooms': 1,
#   'Size': '12 m2'},
#  {'-Title': '青柳荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区喜久井町',
#   'Price': '2.9万円',
#   'Rooms': 1,
#   'Size': '12 m2'},
#  {'-Title': '東京メトロ副都心線 雑司が谷駅 2階建 築45年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区目白台１',
#   'Price': '2.95万円',
#   'Rooms': 1,
#   'Size': '10 m2'},
#  {'-Title': '門間アパ－ト',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区本駒込５',
#   'Price': '3万円',
#   'Rooms': 1,
#   'Size': '12 m2'},
#  {'-Title': '伊豆荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区北新宿２',
#   'Price': '3.3万円',
#   'Rooms': 1,
#   'Size': '12.37 m2'},
#  {'-Title': 'ヒロオハウス',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都渋谷区広尾２',
#   'Price': '2.6万円',
#   'Rooms': 1,
#   'Size': '12.42 m2'},
#  {'-Title': '八幡アパート',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区西片２',
#   'Price': '3.4万円',
#   'Rooms': 1,
#   'Size': '14 m2'},
#  {'-Title': '都営大江戸線 東新宿駅 2階建 築43年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区新宿６',
#   'Price': '3.2万円',
#   'Rooms': 1,
#   'Size': '9.71 m2'},
#  {'-Title': '大橋荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区本郷５',
#   'Price': '3万円',
#   'Rooms': 1,
#   'Size': '8 m2'},
#  {'-Title': '京王新線 幡ヶ谷駅 2階建 築53年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都渋谷区本町６',
#   'Price': '3.5万円',
#   'Rooms': 2,
#   'Size': '30 m2'},
#  {'-Title': 'かなめ荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区北新宿２',
#   'Price': '3.5万円',
#   'Rooms': 2,
#   'Size': '16.53 m2'},
#  {'-Title': '都営三田線 白山駅 2階建 築57年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区白山４',
#   'Price': '3.3万円',
#   'Rooms': 1,
#   'Size': '12.32 m2'},
#  {'-Title': '東京メトロ南北線 本駒込駅 2階建 築49年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区白山４',
#   'Price': '3.3万円',
#   'Rooms': 1,
#   'Size': '12.32 m2'},
#  {'-Title': '東京メトロ丸ノ内線 茗荷谷駅 2階建 築59年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区千石２',
#   'Price': '3.3万円',
#   'Rooms': 1,
#   'Size': '10 m2'},
#  {'-Title': '鈴木荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区西早稲田１',
#   'Price': '3.5万円',
#   'Rooms': 1,
#   'Size': '10 m2'},
#  {'-Title': '茗荷谷アパート',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区千石２',
#   'Price': '3.3万円',
#   'Rooms': 1,
#   'Size': '10 m2'},
#  {'-Title': '狩野荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区弁天町',
#   'Price': '3.4万円',
#   'Rooms': 1,
#   'Size': '9.75 m2'},
#  {'-Title': '静和荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区新宿６',
#   'Price': '3.3万円',
#   'Rooms': 1,
#   'Size': '9.71 m2'},
#  {'-Title': '東京メトロ丸ノ内線 四ツ谷駅 2階建 築59年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区若葉２',
#   'Price': '3.3万円',
#   'Rooms': 1,
#   'Size': '9.12 m2'},
#  {'-Title': '持田アパート',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区矢来町',
#   'Price': '3.6万円',
#   'Rooms': 1,
#   'Size': '14 m2'},
#  {'-Title': '栗林方',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区早稲田町',
#   'Price': '3.5万円',
#   'Rooms': 1,
#   'Size': '13.83 m2'},
#  {'-Title': '第２白樺荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区大塚２',
#   'Price': '3.5万円',
#   'Rooms': 1,
#   'Size': '13 m2'},
#  {'-Title': '五月荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区白山４',
#   'Price': '3.4万円',
#   'Rooms': 1,
#   'Size': '12.38 m2'},
#  {'-Title': 'さつき荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区白山４',
#   'Price': '3.4万円',
#   'Rooms': 1,
#   'Size': '12.3 m2'},
#  {'-Title': '八木コーポ',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区西早稲田３',
#   'Price': '3.4万円',
#   'Rooms': 1,
#   'Size': '12 m2'},
#  {'-Title': '若松荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区弁天町',
#   'Price': '3.3万円',
#   'Rooms': 1,
#   'Size': '10 m2'},
#  {'-Title': '馬場下荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区馬場下町',
#   'Price': '3.5万円',
#   'Rooms': 1,
#   'Size': '15 m2'},
#  {'-Title': '第一富士川ビル',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区四谷４',
#   'Price': '3.3万円',
#   'Rooms': 1,
#   'Size': '13 m2'},
#  {'-Title': '山田アパート',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区改代町',
#   'Price': '3.7万円',
#   'Rooms': 1,
#   'Size': '13 m2'},
#  {'-Title': '増田アパ－ト',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区本郷１',
#   'Price': '3.7万円',
#   'Rooms': 1,
#   'Size': '13 m2'},
#  {'-Title': '大墨荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区山吹町',
#   'Price': '3.7万円',
#   'Rooms': 1,
#   'Size': '9.92 m2'},
#  {'-Title': '東京メトロ日比谷線 広尾駅 2階建 築54年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都港区南麻布４',
#   'Price': '3.5万円',
#   'Rooms': 1,
#   'Size': '8 m2'},
#  {'-Title': '真鍋アパ－ト',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区千駄木５',
#   'Price': '3.8万円',
#   'Rooms': 1,
#   'Size': '17 m2'},
#  {'-Title': '川畑荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区神楽坂６',
#   'Price': '3.8万円',
#   'Rooms': 1,
#   'Size': '12.4 m2'},
#  {'-Title': '川畑荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区神楽坂６',
#   'Price': '3.8万円',
#   'Rooms': 1,
#   'Size': '12.4 m2'},
#  {'-Title': 'アパートメント小石川植物園',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区白山３',
#   'Price': '3.5万円',
#   'Rooms': 1,
#   'Size': '10 m2'},
#  {'-Title': '東京メトロ副都心線 西早稲田駅 2階建 築42年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区西早稲田２',
#   'Price': '3.5万円',
#   'Rooms': 1,
#   'Size': '9 m2'},
#  {'-Title': '都営新宿線 曙橋駅 3階建 築44年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区住吉町',
#   'Price': '3.5万円',
#   'Rooms': 1,
#   'Size': '8 m2'},
#  {'-Title': '長谷川アパート',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都渋谷区本町４',
#   'Price': '3.9万円',
#   'Rooms': 1,
#   'Size': '20 m2'},
#  {'-Title': '細谷荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都渋谷区幡ヶ谷２',
#   'Price': '3.9万円',
#   'Rooms': 1,
#   'Size': '18 m2'},
#  {'-Title': 'ＪＲ山手線 恵比寿駅 2階建 築71年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都渋谷区恵比寿３',
#   'Price': '3.7万円',
#   'Rooms': 1,
#   'Size': '11 m2'},
#  {'-Title': 'ヴェーフェルハウス',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区本駒込５',
#   'Price': '3.1万円',
#   'Rooms': 1,
#   'Size': '3.92 m2'},
#  {'-Title': 'ヴァーフェルハウス本駒込',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区本駒込５',
#   'Price': '3.1万円',
#   'Rooms': 1,
#   'Size': '3.92 m2'},
#  {'-Title': 'ＪＲ山手線 駒込駅 5階建 築11年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区本駒込５',
#   'Price': '3.1万円',
#   'Rooms': 1,
#   'Size': '3.4 m2'},
#  {'-Title': 'Ｎ・本郷荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区本郷６',
#   'Price': '3.8万円',
#   'Rooms': 1,
#   'Size': '13 m2'},
#  {'-Title': '小林アパート',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区榎町',
#   'Price': '3.78万円',
#   'Rooms': 1,
#   'Size': '7.44 m2'},
#  {'-Title': '大森荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区水道１',
#   'Price': '4万円',
#   'Rooms': 1,
#   'Size': '17.19 m2'},
#  {'-Title': 'むつみ荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都中央区月島３',
#   'Price': '4万円',
#   'Rooms': 1,
#   'Size': '16 m2'},
#  {'-Title': '宮本アパート',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区根津２',
#   'Price': '4万円',
#   'Rooms': 1,
#   'Size': '13 m2'},
#  {'-Title': '東京メトロ南北線 白金高輪駅 2階建 築49年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都港区白金５',
#   'Price': '3.8万円',
#   'Rooms': 1,
#   'Size': '13 m2'},
#  {'-Title': '清水ビル',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区矢来町',
#   'Price': '4万円',
#   'Rooms': 1,
#   'Size': '12.38 m2'},
#  {'-Title': '都営三田線 白山駅 5階建 築25年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区白山１',
#   'Price': '3.2万円',
#   'Rooms': 1,
#   'Size': '11 m2'},
#  {'-Title': '都営三田線 千石駅 2階建 築55年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区千石２',
#   'Price': '4万円',
#   'Rooms': 1,
#   'Size': '9.9 m2'},
#  {'-Title': 'ＴＣＲＥ文京白山',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区白山１',
#   'Price': '3.2万円',
#   'Rooms': 1,
#   'Size': '9.8 m2'},
#  {'-Title': '神楽坂アパート',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区神楽坂２',
#   'Price': '4万円',
#   'Rooms': 1,
#   'Size': '9.72 m2'},
#  {'-Title': '京王新線 幡ヶ谷駅 2階建 築62年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都渋谷区幡ヶ谷１',
#   'Price': '4万円',
#   'Rooms': 1,
#   'Size': '7.1 m2'},
#  {'-Title': 'モン・リブレ・ジョリ',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区中落合４',
#   'Price': '3万円',
#   'Rooms': 1,
#   'Size': '6.6 m2'},
#  {'-Title': 'ＪＲ山手線 神田駅 4階建 築38年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都千代田区神田北乗物町',
#   'Price': '4万円',
#   'Rooms': 1,
#   'Size': '4.55 m2'},
#  {'-Title': 'ＪＲ山手線 高田馬場駅 2階建 築41年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区高田馬場４',
#   'Price': '3.8万円',
#   'Rooms': 1,
#   'Size': '12 m2'},
#  {'-Title': '東京メトロ有楽町線 護国寺駅 2階建 築38年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区目白台２',
#   'Price': '3.8万円',
#   'Rooms': 1,
#   'Size': '25 m2'},
#  {'-Title': 'ＪＲ山手線 原宿駅 2階建 築56年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都渋谷区神宮前２',
#   'Price': '3.8万円',
#   'Rooms': 1,
#   'Size': '8.26 m2'},
#  {'-Title': 'エコー中落合',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区中落合４',
#   'Price': '4.2万円',
#   'Rooms': 1,
#   'Size': '47.14 m2'},
#  {'-Title': '山田荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区大塚６',
#   'Price': '4.2万円',
#   'Rooms': 1,
#   'Size': '20.66 m2'},
#  {'-Title': '東京メトロ南北線 本駒込駅 2階建 築39年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区千駄木５',
#   'Price': '4万円',
#   'Rooms': 1,
#   'Size': '18 m2'},
#  {'-Title': 'ＪＲ山手線 新宿駅 2階建 築48年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区西新宿４',
#   'Price': '4万円',
#   'Rooms': 1,
#   'Size': '14.5 m2'},
#  {'-Title': '吾妻荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区西新宿４',
#   'Price': '4万円',
#   'Rooms': 1,
#   'Size': '14.5 m2'},
#  {'-Title': '琴富貴荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区須賀町',
#   'Price': '4.2万円',
#   'Rooms': 1,
#   'Size': '14.04 m2'},
#  {'-Title': '吉澤荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区関口１',
#   'Price': '3.9万円',
#   'Rooms': 1,
#   'Size': '13 m2'},
#  {'-Title': '都営大江戸線 落合南長崎駅 3階建 築26年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区中落合４',
#   'Price': '4.2万円',
#   'Rooms': 1,
#   'Size': '12 m2'},
#  {'-Title': '日本館',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区高田馬場１',
#   'Price': '4.2万円',
#   'Rooms': 1,
#   'Size': '9.72 m2'},
#  {'-Title': 'カーサ早稲田',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区西早稲田１',
#   'Price': '4.3万円',
#   'Rooms': 1,
#   'Size': '17.5 m2'},
#  {'-Title': 'OTOMIGUS目白台',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区目白台２',
#   'Price': '3.8万円',
#   'Rooms': 1,
#   'Size': '9.7 m2'},
#  {'-Title': 'ＪＲ山手線 新大久保駅 4階建 築42年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区百人町２',
#   'Price': '4.3万円',
#   'Rooms': 1,
#   'Size': '9 m2'},
#  {'-Title': 'ＪＲ山手線 池袋駅 2階建 築50年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区大塚６',
#   'Price': '2.95万円',
#   'Rooms': 1,
#   'Size': '4.65 m2'},
#  {'-Title': '東京メトロ東西線 落合駅 2階建 築36年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区上落合３',
#   'Price': '4.2万円',
#   'Rooms': 1,
#   'Size': '12 m2'},
#  {'-Title': '東京メトロ有楽町線 護国寺駅 2階建 築39年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区目白台２',
#   'Price': '4.3万円',
#   'Rooms': 1,
#   'Size': '10.77 m2'},
#  {'-Title': 'AQUAレジデンス中井',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区上落合３',
#   'Price': '4.2万円',
#   'Rooms': 1,
#   'Size': '7.7 m2'},
#  {'-Title': '都営大江戸線 中井駅 3階建 築29年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区上落合３',
#   'Price': '4.2万円',
#   'Rooms': 1,
#   'Size': '7.7 m2'},
#  {'-Title': '村上荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区南山伏町',
#   'Price': '4.5万円',
#   'Rooms': 1,
#   'Size': '21.45 m2'},
#  {'-Title': '東京メトロ東西線 早稲田駅 2階建 築39年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区早稲田鶴巻町',
#   'Price': '4.5万円',
#   'Rooms': 1,
#   'Size': '17 m2'},
#  {'-Title': '西新宿５丁目鈴木荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区西新宿５',
#   'Price': '4.5万円',
#   'Rooms': 1,
#   'Size': '16 m2'},
#  {'-Title': '東京メトロ東西線 神楽坂駅 5階建 築36年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区天神町',
#   'Price': '4.5万円',
#   'Rooms': 1,
#   'Size': '14.85 m2'},
#  {'-Title': '都営三田線 春日駅 2階建 築52年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区本郷５',
#   'Price': '4.5万円',
#   'Rooms': 1,
#   'Size': '14 m2'},
#  {'-Title': '坂田荘',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都港区三田１',
#   'Price': '4.5万円',
#   'Rooms': 1,
#   'Size': '14 m2'},
#  {'-Title': 'Ｙ・Ｄ・Ｉハウス',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区赤城下町',
#   'Price': '4.2万円',
#   'Rooms': 1,
#   'Size': '11.49 m2'},
#  {'-Title': 'コーポ宮本',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区上落合３',
#   'Price': '4.5万円',
#   'Rooms': 1,
#   'Size': '11 m2'},
#  {'-Title': '東京メトロ東西線 落合駅 3階建 築35年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区上落合３',
#   'Price': '4.5万円',
#   'Rooms': 1,
#   'Size': '11 m2'},
#  {'-Title': 'ライブコア中井II',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区中落合３',
#   'Price': '4.3万円',
#   'Rooms': 1,
#   'Size': '7.52 m2'},
#  {'-Title': '都営大江戸線 東新宿駅 5階建 築35年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都新宿区新宿７',
#   'Price': '3.5万円',
#   'Rooms': 1,
#   'Size': '6 m2'},
#  {'-Title': '東京メトロ銀座線 末広町駅 4階建 築33年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都千代田区外神田２',
#   'Price': '4万円',
#   'Rooms': 1,
#   'Size': '4.6 m2'},
#  {'-Title': '東京メトロ丸ノ内線 新大塚駅 2階建 築45年',
#   'Link': '\n詳細を見る',
#   'Locality': '東京都文京区大塚６',
#   'Price': '4.5万円',
#   'Rooms': 1,
#   'Size': '13.2 m2'}]

# %%
import pandas
df=pandas.DataFrame(l)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-ae7e0c185c78> in <module>()
# ----> 1 import pandas
#       2 df=pandas.DataFrame(l)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df
# Out:
#                       -Title      Locality   Price  Rooms      Size
# 0                        久松邸    東京都文京区目白台２   2.5万円      1   11.6 m2
# 1                        名越荘    東京都新宿区赤城下町   2.6万円      1    9.9 m2
# 2    東京メトロ千代田線 千駄木駅 2階建 築43年    東京都文京区千駄木１   2.6万円      1     10 m2
# 3                         司荘    東京都新宿区北新宿２   2.5万円      1      9 m2
# 4                     川村アパート    東京都新宿区喜久井町   2.6万円      1   8.25 m2
# 5     都営大江戸線 落合南長崎駅 2階建 築41年    東京都新宿区西落合３   2.6万円      1   9.72 m2
# 6                        大和荘    東京都文京区本駒込４   2.5万円      1   10.5 m2
# 7    東京メトロ千代田線 千駄木駅 2階建 築49年    東京都文京区千駄木３   2.9万円      1  12.38 m2
# 8                     寺田アパート     東京都文京区千石４   2.6万円      1      9 m2
# 9                        河野荘    東京都渋谷区代々木５   2.9万円      1     10 m2
# 10                       高栄荘    東京都文京区千駄木５   2.8万円      1    9.9 m2
# 11        ＪＲ山手線 巣鴨駅 2階建 築55年     東京都文京区千石４   2.6万円      1    8.7 m2
# 12                       三枝荘   東京都新宿区高田馬場４   2.9万円      1  10.01 m2
# 13                       山崎荘     東京都渋谷区本町４     3万円      1   12.8 m2
# 14    東京メトロ南北線 東大前駅 2階建 築38年     東京都文京区本郷６   2.9万円      1     12 m2
# 15                   もたいアパート    東京都文京区千駄木５     3万円      1  11.34 m2
# 16    東京メトロ東西線 早稲田駅 2階建 築56年   東京都新宿区早稲田南町   2.9万円      1     10 m2
# 17                    早川荘　別館   東京都新宿区早稲田南町   2.9万円      1     10 m2
# 18        京王新線 幡ヶ谷駅 2階建 築54年    東京都渋谷区幡ヶ谷１     3万円      1   9.72 m2
# 19                      五十嵐荘   東京都新宿区早稲田南町   2.4万円      1   9.07 m2
# 20      ＪＲ山手線 高田馬場駅 2階建 築46年   東京都新宿区高田馬場４   2.7万円      1      8 m2
# 21                       狩野荘     東京都新宿区弁天町   2.9万円      1   7.43 m2
# 22                    プティハウス     東京都新宿区若松町     3万円      1    4.6 m2
# 23                   越後屋アパート    東京都新宿区北新宿４   2.9万円      1     12 m2
# 24       ＪＲ中央線 東中野駅 2階建 築40年    東京都新宿区北新宿４   2.9万円      1     12 m2
# 25                       野口荘     東京都文京区白山２     3万円      2   13.2 m2
# 26   都営大江戸線 西新宿五丁目駅 2階建 築47年     東京都渋谷区本町４     3万円      1     17 m2
# 27     都営大江戸線 牛込柳町駅 3階建 築49年    東京都新宿区喜久井町   2.9万円      1     12 m2
# 28                       青柳荘    東京都新宿区喜久井町   2.9万円      1     12 m2
# 29    東京メトロ東西線 早稲田駅 3階建 築42年  東京都新宿区早稲田鶴巻町     3万円      1  11.57 m2
# ..                       ...           ...     ...    ...       ...
# 90                       吾妻荘    東京都新宿区西新宿４     4万円      1   14.5 m2
# 91        ＪＲ山手線 新宿駅 2階建 築48年    東京都新宿区西新宿４     4万円      1   14.5 m2
# 92                      琴富貴荘     東京都新宿区須賀町   4.2万円      1  14.04 m2
# 93                       吉澤荘     東京都文京区関口１   3.9万円      1     13 m2
# 94    都営大江戸線 落合南長崎駅 3階建 築26年    東京都新宿区中落合４   4.2万円      1     12 m2
# 95                       日本館   東京都新宿区高田馬場１   4.2万円      1   9.72 m2
# 96                    カーサ早稲田   東京都新宿区西早稲田１   4.3万円      1   17.5 m2
# 97               OTOMIGUS目白台    東京都文京区目白台２   3.8万円      1    9.7 m2
# 98      ＪＲ山手線 新大久保駅 4階建 築42年    東京都新宿区百人町２   4.3万円      1      9 m2
# 99        ＪＲ山手線 池袋駅 2階建 築50年     東京都文京区大塚６  2.95万円      1   4.65 m2
# 100                      野中荘    東京都渋谷区神宮前２     4万円      1   8.26 m2
# 101    東京メトロ東西線 落合駅 2階建 築36年    東京都新宿区上落合３   4.2万円      1     12 m2
# 102  東京メトロ有楽町線 護国寺駅 2階建 築39年    東京都文京区目白台２   4.3万円      1  10.77 m2
# 103              AQUAレジデンス中井    東京都新宿区上落合３   4.2万円      1    7.7 m2
# 104       西武新宿線 中井駅 3階建 築29年    東京都新宿区上落合３   4.2万円      1    7.7 m2
# 105                      村上荘    東京都新宿区南山伏町   4.5万円      1  21.45 m2
# 106   東京メトロ東西線 早稲田駅 2階建 築39年  東京都新宿区早稲田鶴巻町   4.5万円      1     17 m2
# 107                西新宿５丁目鈴木荘    東京都新宿区西新宿５   4.5万円      1     16 m2
# 108   東京メトロ東西線 神楽坂駅 5階建 築36年     東京都新宿区天神町   4.5万円      1  14.85 m2
# 109                      坂田荘      東京都港区三田１   4.5万円      1     14 m2
# 110       都営三田線 春日駅 2階建 築52年     東京都文京区本郷５   4.5万円      1     14 m2
# 111                 Ｙ・Ｄ・Ｉハウス    東京都新宿区赤城下町   4.2万円      1  11.49 m2
# 112                    コーポ宮本    東京都新宿区上落合３   4.5万円      1     11 m2
# 113    東京メトロ東西線 落合駅 3階建 築35年    東京都新宿区上落合３   4.5万円      1     11 m2
# 114                ライブコア中井II    東京都新宿区中落合３   4.3万円      1   7.52 m2
# 115     都営大江戸線 東新宿駅 5階建 築35年     東京都新宿区新宿７   3.5万円      1      6 m2
# 116   東京メトロ銀座線 末広町駅 4階建 築33年   東京都千代田区外神田２     4万円      1    4.6 m2
# 117  東京メトロ丸ノ内線 新大塚駅 2階建 築45年     東京都文京区大塚６   4.5万円      1   13.2 m2
# 118                    カーサ中井     東京都新宿区中井１   4.4万円      1     10 m2
# 119                      久万荘     東京都文京区大塚６   4.5万円      1     10 m2
#
# [120 rows x 5 columns]

# %%
df.to_csv("Output.csv")
